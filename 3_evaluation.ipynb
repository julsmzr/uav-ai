# %% [markdown]
# # Evaluation Notebook
#
# ### This Jupyter Notebook contains all implemented methods to run the statistical analysis of the three proposed models.
#
# <span style="color:#FFC000">Note: Make sure you have completed walking through the experiments notebook and the results are available for evaluation. In case replication is not desired, feel free to use the provided results.</span>
#
# ---

# %% [markdown]
# ## Statistical Analysis
#
# The following will automatically rerun all implemented evaluations and store the results as csv in results/statistical_analysis.txt

# %%
from uav.evaluation.run import run_full_evaluation

run_full_evaluation(
    metrics_csv_filepath="results/metrics.csv", 
    stat_results_csv_filepath="results/statistical_analysis.csv",
    eff_results_csv_filepath="results/effect_size.csv",
    metric_results_csv_filepath="results/metric_results.csv",
    force_recreate=True,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from uav.evaluation.run import run_full_evaluation
#       3 run_full_evaluation(
#       4     metrics_csv_filepath="results/metrics.csv",
#       5     stat_results_csv_filepath="results/statistical_analysis.csv",
#    (...)      8     force_recreate=True,
#       9 )
#
# File ~/workspace/pwr/ai/uav/evaluation/run.py:6
#       4 from uav.evaluation.utils import data_generator, append_eval_results, write_effect_size_results, write_metric_results, clean_csv_file
#       5 from uav.evaluation.models import EffectSizeResult, MetricResult, Metric
# ----> 6 from uav.evaluation.implementations import SciPyEvaluation, REvaluation, PinguoinEvaluation, STACEvaluation, StatsmodelsHommelwithScipyEvaluation, StatsmodelsHommelwithREvaluation
# ...

# %% [markdown]
# ### Visualizations

# %%
from uav.visualization.run import run_all
from uav.evaluation.models import FullAnalaysisRegistry

run_all(
    results_filepath="results/statistical_analysis.csv",
    metrics_csv_filepath="results/metrics.csv",
    friedman_png_filepath="results/visualizations/friedman.png",
    wilcoxon_png_filepath="results/visualizations/wilcoxon.png",
    metrics_violin_plots_png_filepath="results/visualizations/metrics_violin_plots.png",
    full_analysis_png_filepath_base="results/visualizations/",
    full_analyses=[
        FullAnalaysisRegistry.R,
        FullAnalaysisRegistry.SCIPY_STATSMODELS
    ]
)
# Out:
# /Users/julian/workspace/pwr/ai/uav/visualization/visualization.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# /Users/julian/workspace/pwr/ai/uav/visualization/visualization.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels, fontweight='bold', fontsize=9)
# /Users/julian/workspace/pwr/ai/uav/visualization/visualization.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels, fontweight='bold', fontsize=9)
# ...
