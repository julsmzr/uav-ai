# %% [markdown]
# # Experiments Notebook
#
# ### This Jupyter Notebook contains all executed experiments and allows for reproduction of the results.
#
# <span style="color:#FFC000">Note: Make sure you have completed setting up the development environment, as described in the *README.md*, as well as prepared the dataset by walking through the *setup.ipynb* notebook. Then make sure to select the local venv as kernel.</span>
#
# ---

# %% [markdown]
# ### Path manipulation
#
# To allow package imports, please run this cell below to add the <b>uav</b> package to path.

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# ### Seed Generation
#
# The script below will generate n seeds using secure random number generation and md5 hashing

# %%
import secrets
import hashlib

n = 7

for i in range(n):
    randnum = secrets.randbelow(100_000_000_000)
    seed_hex = hashlib.md5(str(randnum).encode()).hexdigest()
    seed_int = int(seed_hex, 16) % 2**32 - 1
    print(seed_int)
# Out:
# 4140620135
# 1132905197
# 3754523883
# 3492508408
# 3378715402
# 4213948446
# 1521997286
# 1377995568
# 1449566991

# %% [markdown]
# ### Configuration
# The following cells allows configuration of the experiments

# %%
SEEDS = [    
4140620135, # StratifiedShuffleSplit
1132905197, # RepeatedStratifiedKFold
3754523883, # |
3492508408, # |
3378715402, # Model Seeds
4213948446, # |
1521997286, # |
]

EXPERIMENT_NAMES = [
    "VISIBLE",
    "INFRARED",
    "VISIBLE_INFRARED"
]

# RSKF
N_SPLITS = 5
N_REPEATS = 5

FOLD_SIZE = 200

# %% [markdown]
# ### Experiment Creation
#
# The following cell will utilize the scikit-learn library to subsample the dataset (stratified) and then create the fold indices for data splitting in the experiments.
#
# They will be stored in <b>experiments/rskf_splits.npy</b>.

# %%
from uav.experiments.create import create_experiments

create_experiments(
    seeds=SEEDS[:2],
    source_dir="../datasets/anti-uav300",
    target_filepath = "../experiments/rskf_splits.npy",
    fold_size=FOLD_SIZE,
    n_splits=N_SPLITS, 
    n_repeats=N_REPEATS,
    )
# Out:
# Processing Sequences: 100%|██████████| 318/318 [00:10<00:00, 31.25it/s]
# Original X shape: (296901,)
# Original stratification labels: (array([0, 1]), array([ 16683, 280218]))
# Sampled X shape: (1000,)
# Sampled stratification labels: (array([0, 1]), array([ 56, 944]))
# Saved RSKF config to ../experiments/rskf_splits.npy.

# %% [markdown]
# ### Experiment Execution
#
# The following cell will run all training experiments one by one and store the metric results of each single training as a row in <b>metrics.txt</b>.
#
# The script automatically resumes training in case of interruptions and cleans partially completed sessions.

# %%
from uav.experiments.run import run_experiments

run_experiments(
    experiment_rskf_file_npy="../experiments/rskf_splits.npy",
    metrics_file_txt="../results/metrics.csv",
    model_seeds=SEEDS[2:7],
    epochs=20,
    model_weight_path="../models/weights/yolo12n.pt",
    run_dir="../results/exp_train_runs"
    )
# Out:
# Processing fold 0
# Running vz-3754523883 ...
# New https://pypi.org/project/ultralytics/8.3.228 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpdnie_hyd/cfg.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../models/weights/yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=vz-3754523883-f_0_train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../results/exp_train_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=3754523883, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,243 parameters, 2,568,227 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2975.0±999.3 MB/s, size: 98.2 KB)
# train: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpdnie_hyd/train/labels... 800 images, 45 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 6.5Kit/s 0.1s0.1s
# train: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpdnie_hyd/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3115.6±669.8 MB/s, size: 107.6 KB)
# val: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpdnie_hyd/val/labels... 200 images, 11 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 6.6Kit/s 0.0s
# val: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpdnie_hyd/val/labels.cache
# Plotting labels to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_train
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1      6.32G      1.774      3.056      1.183         30        640: 100% ━━━━━━━━━━━━ 50/50 0.9it/s 57.9s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 0.8it/s 8.8s1.2ss
#                    all        200        189    0.00293      0.931    0.00847    0.00342
#
# 1 epochs completed in 0.019 hours.
# Optimizer stripped from /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_train/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_train/weights/best.pt, 5.5MB
#
# Validating /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_train/weights/best.pt...
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s0.9ss
#                    all        200        189    0.00293      0.931    0.00848    0.00342
# Speed: 0.1ms preprocess, 7.2ms inference, 0.0ms loss, 6.4ms postprocess per image
# Results saved to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_train
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2473.8±1368.6 MB/s, size: 106.6 KB)
# val: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpdnie_hyd/val/labels.cache... 200 images, 11 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 1.0Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.9it/s 4.5s0.3s
#                    all        200        189    0.00293      0.931    0.00848    0.00342
# Speed: 0.2ms preprocess, 5.6ms inference, 0.0ms loss, 4.0ms postprocess per image
# Saving /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_val/predictions.json...
# Results saved to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_0_val
# Processing fold 1
# Running vz-3754523883 ...
# New https://pypi.org/project/ultralytics/8.3.228 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmp0tnz0_wf/cfg.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../models/weights/yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=vz-3754523883-f_1_train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../results/exp_train_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=3754523883, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,243 parameters, 2,568,227 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3726.1±873.6 MB/s, size: 95.6 KB)
# train: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmp0tnz0_wf/train/labels... 800 images, 45 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 6.8Kit/s 0.1s0.1s
# train: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmp0tnz0_wf/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4739.4±1380.9 MB/s, size: 116.1 KB)
# val: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmp0tnz0_wf/val/labels... 200 images, 11 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 6.8Kit/s 0.0s
# val: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmp0tnz0_wf/val/labels.cache
# Plotting labels to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_train
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1      6.35G      1.739      2.971      1.169         25        640: 100% ━━━━━━━━━━━━ 50/50 0.8it/s 58.8s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.8s1.2ss
#                    all        200        189     0.0027      0.857    0.00649    0.00208
#
# 1 epochs completed in 0.019 hours.
# Optimizer stripped from /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_train/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_train/weights/best.pt, 5.5MB
#
# Validating /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_train/weights/best.pt...
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.6s0.8ss
#                    all        200        189     0.0027      0.857     0.0065    0.00209
# Speed: 0.1ms preprocess, 6.2ms inference, 0.0ms loss, 7.2ms postprocess per image
# Results saved to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_train
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3413.7±518.2 MB/s, size: 121.9 KB)
# val: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmp0tnz0_wf/val/labels.cache... 200 images, 11 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 1.0Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.3it/s 3.9s0.3s
#                    all        200        189     0.0027      0.857     0.0065    0.00209
# Speed: 0.1ms preprocess, 4.6ms inference, 0.0ms loss, 4.5ms postprocess per image
# Saving /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_val/predictions.json...
# Results saved to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_1_val
# Processing fold 2
# Running vz-3754523883 ...
# New https://pypi.org/project/ultralytics/8.3.228 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpwqkbl6lh/cfg.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../models/weights/yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=vz-3754523883-f_2_train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../results/exp_train_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_2_train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=3754523883, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,243 parameters, 2,568,227 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3363.9±790.6 MB/s, size: 98.8 KB)
# train: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpwqkbl6lh/train/labels... 800 images, 45 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 6.2Kit/s 0.1s0.1s
# train: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpwqkbl6lh/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4593.8±1447.3 MB/s, size: 110.9 KB)
# val: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpwqkbl6lh/val/labels... 200 images, 11 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 6.2Kit/s 0.0s
# val: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpwqkbl6lh/val/labels.cache
# Plotting labels to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_2_train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3754523883-f_2_train
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1      6.36G      1.909      4.804      1.191         32        640: 8% ╸─────────── 4/50 0.7it/s 5.9s<1:05
# Run cancelled via KeyboardInterrupt.
# Processing fold 0
# Running vz-3492508408 ...
# New https://pypi.org/project/ultralytics/8.3.228 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.219 🚀 Python-3.13.5 torch-2.9.0 MPS (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpg2_u046w/cfg.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../models/weights/yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=vz-3492508408-f_0_train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../results/exp_train_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3492508408-f_0_train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=3492508408, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,243 parameters, 2,568,227 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1712.2±1857.5 MB/s, size: 85.8 KB)
# train: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpg2_u046w/train/labels... 800 images, 45 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 8.1Kit/s 0.1s
# train: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpg2_u046w/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2922.6±978.1 MB/s, size: 89.2 KB)
# val: Scanning /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpg2_u046w/val/labels... 200 images, 11 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 7.0Kit/s 0.0s
# val: New cache created: /private/var/folders/xw/45g67_dd7glf1l755cb4gtgc0000gn/T/tmpg2_u046w/val/labels.cache
# Plotting labels to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3492508408-f_0_train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/julian/workspace/pwr/ai/results/exp_train_runs/vz-3492508408-f_0_train
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1       6.4G      1.755      4.879      1.152         32        640: 12% ━─────────── 6/50 0.6it/s 9.8s<1:11
