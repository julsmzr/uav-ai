# %% [markdown]
# # Setup Notebook
#
# ### This Jupyter Notebook contains all necessary steps in order to set up the dataset Anti-UAV300.
#
# If you do not want to customize anything in the structure, just run the setup function in this cell below. Otherwise feel free to read and work through it step by step.

# %%
from uav.setup.autosetup import automated_setup

input("Make sure about 60GB are available on your disk. Press Enter to continue.")

automated_setup(verbose=True)
# Out:
# Running automated setup.
# Downloading...
# Downloading...
# From (original): https://drive.google.com/uc?id=1NPYaop35ocVTYWHOYQQHn8YHsM9jmLGr
# From (redirected): https://drive.google.com/uc?id=1NPYaop35ocVTYWHOYQQHn8YHsM9jmLGr&confirm=t&uuid=c0f6e3c7-3dfd-44c2-b49f-32c7ef46c931
# To: /Users/julian/workspace/pwr/ai/datasets/anti-uav300-raw.zip
# 100%|██████████| 6.04G/6.04G [13:16<00:00, 7.58MB/s]
# Dataset download completed.
# Zip removed successfully
# File extracted to datasets/anti-uav300-raw
# Dataset was downloaded and extracted to datasets/anti-uav300-raw.
# Something went wrong. Please rerun the download.
# Formatting...
# datasets/anti-uav300-raw
# Starting Extraction of Data...
# Extracting test subset: 100%|██████████| 91/91 [00:00<00:00, 553964.68it/s]
# Extracting train subset: 100%|██████████| 160/160 [00:00<00:00, 2193100.13it/s]
# Extracting val subset: 100%|██████████| 67/67 [00:00<00:00, 1307062.18it/s]
# Statistics successfully saved to datasets/anti-uav300/statistics.json.
# Source directory was removed successfully.
# Conversion done!
# Something went wrong. Please rerun the processing.
# Done!

# %% [markdown]
# ## Dataset Anti-UAV300
#
# The Anti-UAV300 Dataset provided by Nan Jiang et. al (2021)[1] contains 300 video sequences, each containing visible light captured via a standard camera sensor and an uncalibrated but synchronized infrared counterpart.
#
# <sub><b>[1] Nan Jiang, Kuiran Wang, Xiaoke Peng, Xuehui Yu, Qiang Wang, Junliang Xing, Guorong Li, Jian Zhao, Guodong Guo, & Zhenjun Han. (2021).</b> Anti-UAV: A Large Multi-Modal Benchmark for UAV Tracking.<sub>
#
# ---

# %% [markdown]
# ### Download (6.04GB) and Unzip (6.73GB)

# %%
from uav.setup.download_data import download_and_extract

input("Make sure about 15GB are available on your disk. Press Enter to continue.")

download_and_extract(
    url="https://drive.google.com/uc?id=1NPYaop35ocVTYWHOYQQHn8YHsM9jmLGr", # Dataset provided via GitHub: https://github.com/ucas-vg/Anti-UAV
    zip_path="../datasets/anti-uav300-raw.zip",
    extract_dir="../datasets/anti-uav300-raw",
    verbose=True,
    remove_zip=False
)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1NPYaop35ocVTYWHOYQQHn8YHsM9jmLGr
# From (redirected): https://drive.google.com/uc?id=1NPYaop35ocVTYWHOYQQHn8YHsM9jmLGr&confirm=t&uuid=33617e75-b1d4-4a24-a4cb-301350607657
# To: /Users/julian/workspace/pwr/ai/datasets/anti-uav300-raw.zip
# 100%|██████████| 6.04G/6.04G [24:12<00:00, 4.16MB/s]
# Dataset download completed.
# File extracted to datasets/anti-uav300-raw
# Dataset was downloaded and extracted to datasets/anti-uav300-raw.
# True

# %% [markdown]
# ### Convert into COCO format (52.04GB)
#
# All the subsets are merged and the frames extracted from the mp4 files. Then all the annotations are read and converted into COCO format as proposed by Lin et. al (2015)[2].
#
# For more information on the data formats please see docs/data_processing.md
#
# <sub><b>[2] Tsung-Yi Lin, Michael Maire, Serge Belongie, Lubomir Bourdev, Ross Girshick, James Hays, Pietro Perona, Deva Ramanan, C. Lawrence Zitnick, & Piotr Dollár. (2015).</b> Microsoft COCO: Common Objects in Context.</sub>

# %%
from uav.setup.process_data import process_dataset

input("Make sure about 60GB are available on your disk. Press Enter to continue.")

process_dataset(
    source_dir="../datasets/anti-uav300-raw",
    target_dir="../datasets/anti-uav300",
    verbose=True,
    remove_source=False,
)
# Out:
# datasets/anti-uav300-raw
# Detected Target Directory. Validating...
# Validating test subset: 100%|██████████| 91/91 [00:00<00:00, 297.42it/s]
# Validating train subset: 100%|██████████| 160/160 [00:00<00:00, 211566.41it/s]
# Validating val subset: 100%|██████████| 67/67 [00:00<00:00, 142504.24it/s]
# Sucessfully validated 30 sequences.
# Continuing extraction for 288 remaining sequences...
# bef
# Extracting test subset:   0%|          | 0/91 [00:00<?, ?it/s]
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# Extracting test subset: 100%|██████████| 91/91 [05:30<00:00,  3.63s/it]
# Extracting train subset: 100%|██████████| 160/160 [13:08<00:00,  4.93s/it]
# Extracting val subset: 100%|██████████| 67/67 [05:54<00:00,  5.29s/it]
# Statistics successfully saved to datasets/anti-uav300/statistics.json.
# Conversion done!
# True

# %% [markdown]
# ### Dataset Statistics

# %%
from uav.setup.analyze_data import analyze_data

analyze_data()
# Out:
# to be implemented.
